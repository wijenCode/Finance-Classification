# %% [markdown]
# #Load library

# %%
# !pip install skfeature-chappers
# Out:
# Collecting skfeature-chappers
#   Downloading skfeature_chappers-1.1.0-py3-none-any.whl.metadata (926 bytes)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from skfeature-chappers) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from skfeature-chappers) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from skfeature-chappers) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->skfeature-chappers) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->skfeature-chappers) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->skfeature-chappers) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->skfeature-chappers) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->skfeature-chappers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->skfeature-chappers) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->skfeature-chappers) (1.17.0)
# Downloading skfeature_chappers-1.1.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: skfeature-chappers
# Successfully installed skfeature-chappers-1.1.0

# %%
from mpl_toolkits.axisartist.axislines import SubplotZero
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn
seaborn.set(style='ticks')
import matplotlib.cm as cm
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.svm import SVC
import joblib

# %% [markdown]
# #Load dataset

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/My Drive/tubes ildat
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/tubes ildat
# data_keuangan_labeled.csv	    finance_boosting_model.sav
# dataset_keuangan.csv		    scaler_finance_bagging.sav
# finance_boosting_model_bagging.sav  scaler_finance.sav

# %%
import pandas as pd

file_path = '/content/drive/My Drive/tubes ildat/data_keuangan_labeled.csv'
df = pd.read_csv(file_path)
display(df.head())
# Out:
#          Gaji  Tabungan Lama   Investasi  Pemasukan Lainnya    Tipe  \
# 0  24333000.0      1629000.0   7891000.0          3861000.0  normal
# 1   3535000.0       733000.0    785000.0           659000.0   hemat
# 2  65000000.0      9642000.0  13643000.0         10842000.0   hemat
# 3  54676000.0      5037000.0  18466000.0          4826000.0  normal
# 4  24298000.0      4665000.0   4964000.0          2649000.0   boros
#
#    Bahan Pokok  Protein & Gizi Tambahan  Tempat Tinggal    Sandang  \
# 0    3694000.0                3570000.0      10682000.0   994000.0
# 1     383000.0                 994000.0       1432000.0   134000.0
# 2    7849000.0               13081000.0      24853000.0  1810000.0
# 3    5367000.0               13703000.0      16628000.0  2746000.0
# 4    2169000.0                5477000.0       7866000.0   366000.0
#
#    Konsumsi Praktis  Barang & Jasa Sekunder  Pengeluaran Tidak Esensial  \
# 0         5563000.0               5140000.0                   1282000.0
# 1          438000.0                475000.0                    230000.0
# 2         3819000.0               6465000.0                   2545000.0
# 3         8826000.0              11029000.0                   3489000.0
# 4         8454000.0               6060000.0                   2956000.0
#
#        Pajak   Asuransi  Sosial & Budaya  Tabungan / Investasi  cluster  \
# 0   876000.0   528000.0         458000.0             4950000.0        0
# 1   159000.0   263000.0         174000.0             1062000.0        1
# 2  4910000.0  3580000.0        4686000.0            24775000.0        2
# 3  2308000.0  2015000.0        1759000.0            14771000.0        2
# 4   277000.0   285000.0         438000.0             2300000.0        0
#
#      cluster_label
# 0  Rawan Finansial
# 1  Menengah Stabil
# 2  Sehat Finansial
# 3  Sehat Finansial
# 4  Rawan Finansial

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gaji                        16000 non-null  float64
#  1   Tabungan Lama               16000 non-null  float64
#  2   Investasi                   16000 non-null  float64
#  3   Pemasukan Lainnya           16000 non-null  float64
#  4   Tipe                        16000 non-null  object
#  5   Bahan Pokok                 16000 non-null  float64
#  6   Protein & Gizi Tambahan     16000 non-null  float64
#  7   Tempat Tinggal              16000 non-null  float64
#  8   Sandang                     16000 non-null  float64
#  9   Konsumsi Praktis            16000 non-null  float64
#  10  Barang & Jasa Sekunder      16000 non-null  float64
#  11  Pengeluaran Tidak Esensial  16000 non-null  float64
#  12  Pajak                       16000 non-null  float64
#  13  Asuransi                    16000 non-null  float64
#  14  Sosial & Budaya             16000 non-null  float64
#  15  Tabungan / Investasi        16000 non-null  float64
#  16  cluster                     16000 non-null  int64
#  17  cluster_label               16000 non-null  object
# dtypes: float64(15), int64(1), object(2)
# memory usage: 2.2+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame as defined in the previous code

plt.figure(figsize=(8, 6))
sns.countplot(x='cluster', data=df)
plt.title('Distribution of finance')
plt.xlabel('Finance Status')
plt.ylabel('Count')
plt.show()

# %%
dataset = df.drop(columns='cluster_label')

# %%
mapping_tipe = {
    'hemat': 0,
    'normal': 1,
    'boros': 2
}

dataset['Tipe'] = dataset['Tipe'].map(mapping_tipe)
dataset
# Out:
#              Gaji  Tabungan Lama   Investasi  Pemasukan Lainnya  Tipe  \
# 0      24333000.0      1629000.0   7891000.0          3861000.0     1
# 1       3535000.0       733000.0    785000.0           659000.0     0
# 2      65000000.0      9642000.0  13643000.0         10842000.0     0
# 3      54676000.0      5037000.0  18466000.0          4826000.0     1
# 4      24298000.0      4665000.0   4964000.0          2649000.0     2
# ...           ...            ...         ...                ...   ...
# 15995  38323000.0      4781000.0  11977000.0          6186000.0     2
# 15996  13432000.0      2485000.0   4412000.0          1166000.0     1
# 15997  22432000.0      3639000.0   8754000.0          5595000.0     0
# 15998  22499000.0      4321000.0   7354000.0          2934000.0     0
# 15999  13675000.0      2019000.0   7295000.0          1572000.0     0
#
#        Bahan Pokok  Protein & Gizi Tambahan  Tempat Tinggal    Sandang  \
# 0        3694000.0                3570000.0      10682000.0   994000.0
# 1         383000.0                 994000.0       1432000.0   134000.0
# 2        7849000.0               13081000.0      24853000.0  1810000.0
# 3        5367000.0               13703000.0      16628000.0  2746000.0
# 4        2169000.0                5477000.0       7866000.0   366000.0
# ...            ...                      ...             ...        ...
# 15995    3317000.0                7279000.0      10936000.0  1968000.0
# 15996    2864000.0                3543000.0       7092000.0   382000.0
# 15997    1922000.0                5125000.0      11150000.0   631000.0
# 15998    3641000.0                3978000.0      10231000.0   960000.0
# 15999    2199000.0                3330000.0       7163000.0   235000.0
#
#        Konsumsi Praktis  Barang & Jasa Sekunder  Pengeluaran Tidak Esensial  \
# 0             5563000.0               5140000.0                   1282000.0
# 1              438000.0                475000.0                    230000.0
# 2             3819000.0               6465000.0                   2545000.0
# 3             8826000.0              11029000.0                   3489000.0
# 4             8454000.0               6060000.0                   2956000.0
# ...                 ...                     ...                         ...
# 15995        11867000.0              13335000.0                   6414000.0
# 15996         1506000.0               2290000.0                    719000.0
# 15997         3321000.0               4375000.0                   1056000.0
# 15998         3589000.0               2492000.0                    822000.0
# 15999         2453000.0               1894000.0                    773000.0
#
#            Pajak   Asuransi  Sosial & Budaya  Tabungan / Investasi  cluster
# 0       876000.0   528000.0         458000.0             4950000.0        0
# 1       159000.0   263000.0         174000.0             1062000.0        1
# 2      4910000.0  3580000.0        4686000.0            24775000.0        2
# 3      2308000.0  2015000.0        1759000.0            14771000.0        2
# 4       277000.0   285000.0         438000.0             2300000.0        0
# ...          ...        ...              ...                   ...      ...
# 15995   543000.0   369000.0         594000.0             4709000.0        0
# 15996   353000.0   644000.0         358000.0             1873000.0        1
# 15997  1263000.0  1052000.0        1562000.0             8887000.0        0
# 15998  1472000.0  1425000.0        1161000.0             7332000.0        0
# 15999   755000.0   459000.0        1016000.0             4421000.0        1
#
# [16000 rows x 17 columns]

# %% [markdown]
# #Memisahkan feature dan label

# %%
X = dataset.drop(columns=['cluster'])
y = dataset['cluster']

# %%
X
# Out:
#              Gaji  Tabungan Lama   Investasi  Pemasukan Lainnya  Tipe  \
# 0      24333000.0      1629000.0   7891000.0          3861000.0     1
# 1       3535000.0       733000.0    785000.0           659000.0     0
# 2      65000000.0      9642000.0  13643000.0         10842000.0     0
# 3      54676000.0      5037000.0  18466000.0          4826000.0     1
# 4      24298000.0      4665000.0   4964000.0          2649000.0     2
# ...           ...            ...         ...                ...   ...
# 15995  38323000.0      4781000.0  11977000.0          6186000.0     2
# 15996  13432000.0      2485000.0   4412000.0          1166000.0     1
# 15997  22432000.0      3639000.0   8754000.0          5595000.0     0
# 15998  22499000.0      4321000.0   7354000.0          2934000.0     0
# 15999  13675000.0      2019000.0   7295000.0          1572000.0     0
#
#        Bahan Pokok  Protein & Gizi Tambahan  Tempat Tinggal    Sandang  \
# 0        3694000.0                3570000.0      10682000.0   994000.0
# 1         383000.0                 994000.0       1432000.0   134000.0
# 2        7849000.0               13081000.0      24853000.0  1810000.0
# 3        5367000.0               13703000.0      16628000.0  2746000.0
# 4        2169000.0                5477000.0       7866000.0   366000.0
# ...            ...                      ...             ...        ...
# 15995    3317000.0                7279000.0      10936000.0  1968000.0
# 15996    2864000.0                3543000.0       7092000.0   382000.0
# 15997    1922000.0                5125000.0      11150000.0   631000.0
# 15998    3641000.0                3978000.0      10231000.0   960000.0
# 15999    2199000.0                3330000.0       7163000.0   235000.0
#
#        Konsumsi Praktis  Barang & Jasa Sekunder  Pengeluaran Tidak Esensial  \
# 0             5563000.0               5140000.0                   1282000.0
# 1              438000.0                475000.0                    230000.0
# 2             3819000.0               6465000.0                   2545000.0
# 3             8826000.0              11029000.0                   3489000.0
# 4             8454000.0               6060000.0                   2956000.0
# ...                 ...                     ...                         ...
# 15995        11867000.0              13335000.0                   6414000.0
# 15996         1506000.0               2290000.0                    719000.0
# 15997         3321000.0               4375000.0                   1056000.0
# 15998         3589000.0               2492000.0                    822000.0
# 15999         2453000.0               1894000.0                    773000.0
#
#            Pajak   Asuransi  Sosial & Budaya  Tabungan / Investasi
# 0       876000.0   528000.0         458000.0             4950000.0
# 1       159000.0   263000.0         174000.0             1062000.0
# 2      4910000.0  3580000.0        4686000.0            24775000.0
# 3      2308000.0  2015000.0        1759000.0            14771000.0
# 4       277000.0   285000.0         438000.0             2300000.0
# ...          ...        ...              ...                   ...
# 15995   543000.0   369000.0         594000.0             4709000.0
# 15996   353000.0   644000.0         358000.0             1873000.0
# 15997  1263000.0  1052000.0        1562000.0             8887000.0
# 15998  1472000.0  1425000.0        1161000.0             7332000.0
# 15999   755000.0   459000.0        1016000.0             4421000.0
#
# [16000 rows x 16 columns]

# %% [markdown]
# #Feature Selection

# %%
from skfeature.function.information_theoretical_based import MRMR

# convert menjadi numpy array
X_np = X.values
y_np = y.values

# MRMR sebelum scaling
ranked_index = MRMR.mrmr(X_np, y_np, n_selected_features=X_np.shape[1])

print("\nMRMR Ranking Index:")
print(ranked_index)

# fitur terurut sesuai MRMR
X_mrmr = X_np[:, ranked_index]

print("\nFitur hasil urutan MRMR:")
print(X_mrmr)
# Out:
# MRMR Ranking Index:
# [15 11  7  1  2  3  4 10 14 12  9  6 13  5  0  8]
#
# Fitur hasil urutan MRMR:
# [[ 4950000.  1282000. 10682000. ...  3694000. 24333000.   994000.]
#  [ 1062000.   230000.  1432000. ...   383000.  3535000.   134000.]
#  [24775000.  2545000. 24853000. ...  7849000. 65000000.  1810000.]
#  ...
#  [ 8887000.  1056000. 11150000. ...  1922000. 22432000.   631000.]
#  [ 7332000.   822000. 10231000. ...  3641000. 22499000.   960000.]
#  [ 4421000.   773000.  7163000. ...  2199000. 13675000.   235000.]]

# %% [markdown]
# #Membagi dataset menjadi data training dan data testing

# %%
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_mrmr, y_np, test_size=0.3, random_state=42, stratify=y_np
)

# %% [markdown]
# #Feature scaling

# %%
scaler = StandardScaler()
scaler.fit(X_train_raw)

# save
joblib.dump(scaler, '/content/drive/My Drive/tubes ildat/scaler_finance.sav')

# load (opsional)
scaler = joblib.load('/content/drive/My Drive/tubes ildat/scaler_finance.sav')

# transform
X_train = scaler.transform(X_train_raw)
X_test  = scaler.transform(X_test_raw)

# %% [markdown]
# #Hyperparameter optimization

# %%
from sklearn.model_selection import RandomizedSearchCV
import xgboost as xgb

# defining parameter range
param_distributions = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.7, 0.8, 1.0],
    'colsample_bytree': [0.7, 0.8, 1.0],
    'gamma': [0, 0.1, 0.3]
}

# classifier
classifier = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    tree_method='hist',
    random_state=42
)

# --- RANDOMIZED SEARCH ---
model = RandomizedSearchCV(
    estimator=classifier,
    param_distributions=param_distributions,
    n_iter=20,         # jumlah kombinasi yang dicoba
    scoring='f1_macro',
    cv=5,
    refit=True,
    verbose=3,
    random_state=42
)

model.fit(X_train, y_train)

print("Best Params:", model.best_params_)
print("Best Model:", model.best_estimator_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7;, score=0.986 total time=   3.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7;, score=0.985 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7;, score=0.986 total time=   0.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7;, score=0.985 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.7;, score=0.987 total time=   0.8s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8;, score=0.984 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8;, score=0.988 total time=   1.4s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8;, score=0.985 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8;, score=0.985 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8;, score=0.988 total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.985 total time=   4.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.984 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.985 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.987 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.984 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8;, score=0.985 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8;, score=0.987 total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8;, score=0.985 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8;, score=0.985 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8;, score=0.982 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0;, score=0.977 total time=   0.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0;, score=0.979 total time=   3.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0;, score=0.979 total time=   1.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0;, score=0.972 total time=   0.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0;, score=0.972 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0;, score=0.979 total time=  17.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0;, score=0.977 total time=   4.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0;, score=0.980 total time=   7.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0;, score=0.975 total time=   4.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, n_estimators=200, subsample=1.0;, score=0.977 total time=   4.0s
# [CV 1/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7;, score=0.985 total time=   1.2s
# [CV 2/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7;, score=0.985 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7;, score=0.987 total time=   4.4s
# [CV 4/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7;, score=0.985 total time=   1.9s
# [CV 5/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=100, subsample=0.7;, score=0.986 total time=   1.2s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7;, score=0.961 total time=   0.5s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7;, score=0.959 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7;, score=0.962 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7;, score=0.958 total time=   0.6s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.7;, score=0.956 total time=   0.5s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.8;, score=0.985 total time=  11.0s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.8;, score=0.986 total time=   5.4s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.8;, score=0.986 total time=   2.8s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.8;, score=0.986 total time=   6.7s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=7, n_estimators=300, subsample=0.8;, score=0.985 total time=   3.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7;, score=0.979 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7;, score=0.978 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7;, score=0.977 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7;, score=0.976 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=0.7;, score=0.977 total time=   5.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.977 total time=   2.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.976 total time=   1.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.977 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.974 total time=   1.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.974 total time=   1.8s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8;, score=0.987 total time=   3.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8;, score=0.988 total time=   3.0s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8;, score=0.984 total time=   1.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8;, score=0.987 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=300, subsample=0.8;, score=0.989 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.7;, score=0.986 total time=   2.3s
# [CV 2/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.7;, score=0.987 total time=   2.5s
# [CV 3/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.7;, score=0.986 total time=   7.7s
# [CV 4/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.7;, score=0.985 total time=   2.3s
# [CV 5/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, n_estimators=300, subsample=0.7;, score=0.985 total time=   2.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8;, score=0.979 total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8;, score=0.983 total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8;, score=0.979 total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8;, score=0.974 total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8;, score=0.976 total time=   0.6s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.7;, score=0.986 total time=   6.0s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.7;, score=0.988 total time=   2.1s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.7;, score=0.984 total time=   2.1s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.7;, score=0.988 total time=   2.0s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, n_estimators=300, subsample=0.7;, score=0.988 total time=   2.1s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.966 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.964 total time=   4.1s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.968 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.962 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0;, score=0.958 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.985 total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.986 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.987 total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0;, score=0.985 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.7;, score=0.986 total time=   1.5s
# [CV 2/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.7;, score=0.988 total time=   4.3s
# [CV 3/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.7;, score=0.986 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.7;, score=0.988 total time=   1.5s
# [CV 5/5] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, n_estimators=300, subsample=0.7;, score=0.987 total time=   1.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.972 total time=   2.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.969 total time=   2.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.975 total time=   2.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.969 total time=   5.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=100, subsample=1.0;, score=0.969 total time=   2.2s
# [CV 1/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8;, score=0.984 total time=   0.9s
# [CV 2/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8;, score=0.982 total time=   0.9s
# [CV 3/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8;, score=0.984 total time=   0.9s
# [CV 4/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8;, score=0.980 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8;, score=0.982 total time=   0.9s
# Best Params: {'subsample': 0.7, 'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.05, 'gamma': 0, 'colsample_bytree': 0.7}
# Best Model: XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=0,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None, num_class=3, ...)

# %% [markdown]
# #Hasil prediksi

# %%
predictions = model.predict(X_test)
# print classification report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1648
#            1       0.99      0.99      0.99      1567
#            2       0.99      0.99      0.99      1585
#
#     accuracy                           0.99      4800
#    macro avg       0.99      0.99      0.99      4800
# weighted avg       0.99      0.99      0.99      4800

# %%
#plot confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model, X_test, y_test)
plt.show()

# %% [markdown]
# #Save Model

# %%
import joblib

# save the model to disk
filename = '/content/drive/My Drive/tubes ildat/finance_boosting_model.sav'
joblib.dump(model.best_estimator_, filename)

# load the model from disk
loaded_model = joblib.load(filename)
print(loaded_model)
#result = loaded_model.score(X_test, y_test)
print('Hasil model menggunakan model yang sudah disimpan:',loaded_model.score(X_test, y_test))
print('Hasil model menggunakan model hasil training langsung:',model.score(X_test, y_test))
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=0,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None, num_class=3, ...)
# Hasil model menggunakan model yang sudah disimpan: 0.9872916666666667
# Hasil model menggunakan model hasil training langsung: 0.9873803966721222
